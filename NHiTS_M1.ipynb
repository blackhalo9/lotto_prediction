# %% [markdown]
# # N-HiTS

# %%
# !pip install darts
# Out:
# Collecting darts
#   Downloading darts-0.23.1-py3-none-any.whl (592 kB)
#      -------------------------------------- 592.0/592.0 kB 2.5 MB/s eta 0:00:00
# Collecting lightgbm>=3.2.0
#   Downloading lightgbm-3.3.5-py3-none-win_amd64.whl (1.0 MB)
#      ---------------------------------------- 1.0/1.0 MB 2.4 MB/s eta 0:00:00
# Collecting holidays>=0.11.1
#   Downloading holidays-0.19-py3-none-any.whl (208 kB)
#      -------------------------------------- 208.5/208.5 kB 2.5 MB/s eta 0:00:00
# Collecting nfoursid>=1.0.0
#   Downloading nfoursid-1.0.1-py3-none-any.whl (16 kB)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from darts) (1.23.5)
# Requirement already satisfied: statsmodels>=0.13.0 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from darts) (0.13.5)
# Requirement already satisfied: requests>=2.22.0 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from darts) (2.28.2)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from darts) (3.6.2)
# Collecting pmdarima>=1.8.0
#   Downloading pmdarima-2.0.2-cp38-cp38-win_amd64.whl (571 kB)
#      -------------------------------------- 571.9/571.9 kB 1.4 MB/s eta 0:00:00
# Collecting pyod>=0.9.5
#   Downloading pyod-1.0.7.tar.gz (147 kB)
#      -------------------------------------- 147.7/147.7 kB 2.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting catboost>=1.0.6
#   Downloading catboost-1.1.1-cp38-none-win_amd64.whl (74.0 MB)
#      ---------------------------------------- 74.0/74.0 MB 2.2 MB/s eta 0:00:00
# Collecting xarray>=0.17.0
#   Downloading xarray-2023.1.0-py3-none-any.whl (973 kB)
#      -------------------------------------- 973.1/973.1 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.0.5 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from darts) (1.5.2)
# Collecting xgboost>=1.6.0
#   Downloading xgboost-1.7.3-py3-none-win_amd64.whl (89.1 MB)
#      ---------------------------------------- 89.1/89.1 MB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.3.2 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from darts) (1.9.3)
# Requirement already satisfied: torch>=1.8.0 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from darts) (1.13.1+cu116)
# Collecting prophet>=1.1.1
#   Downloading prophet-1.1.2-py3-none-win_amd64.whl (12.1 MB)
#      ---------------------------------------- 12.1/12.1 MB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=0.16.0 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from darts) (1.1.1)
# Requirement already satisfied: tqdm>=4.60.0 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from darts) (4.64.1)
# Collecting tbats>=1.1.0
#   Downloading tbats-1.1.2-py3-none-any.whl (43 kB)
#      ---------------------------------------- 43.8/43.8 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: pytorch-lightning>=1.5.0 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from darts) (1.6.5)
# Requirement already satisfied: scikit-learn>=1.0.1 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from darts) (1.1.3)
# Collecting shap>=0.40.0
#   Downloading shap-0.41.0-cp38-cp38-win_amd64.whl (435 kB)
#      -------------------------------------- 435.6/435.6 kB 3.9 MB/s eta 0:00:00
# Collecting statsforecast>=1.0.0
#   Downloading statsforecast-1.4.0-py3-none-any.whl (91 kB)
#      ---------------------------------------- 92.0/92.0 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: six in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from catboost>=1.0.6->darts) (1.16.0)
# Collecting plotly
#   Downloading plotly-5.13.0-py2.py3-none-any.whl (15.2 MB)
#      ---------------------------------------- 15.2/15.2 MB 2.6 MB/s eta 0:00:00
# Collecting graphviz
#   Downloading graphviz-0.20.1-py3-none-any.whl (47 kB)
#      ---------------------------------------- 47.0/47.0 kB 2.5 MB/s eta 0:00:00
# Collecting korean-lunar-calendar
#   Downloading korean_lunar_calendar-0.3.1-py3-none-any.whl (9.0 kB)
# Collecting convertdate>=2.3.0
#   Downloading convertdate-2.4.0-py3-none-any.whl (47 kB)
#      ---------------------------------------- 47.9/47.9 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from holidays>=0.11.1->darts) (2.8.2)
# Collecting PyMeeus
#   Downloading PyMeeus-0.5.12.tar.gz (5.8 MB)
#      ---------------------------------------- 5.8/5.8 MB 3.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting hijri-converter
#   Downloading hijri_converter-2.2.4-py3-none-any.whl (14 kB)
# Requirement already satisfied: wheel in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from lightgbm>=3.2.0->darts) (0.37.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from matplotlib>=3.3.0->darts) (9.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from matplotlib>=3.3.0->darts) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from matplotlib>=3.3.0->darts) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from matplotlib>=3.3.0->darts) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from matplotlib>=3.3.0->darts) (22.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from matplotlib>=3.3.0->darts) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from matplotlib>=3.3.0->darts) (1.0.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from pandas>=1.0.5->darts) (2022.7)
# Collecting Cython!=0.29.18,!=0.29.31,>=0.29
#   Downloading Cython-0.29.33-py2.py3-none-any.whl (987 kB)
#      -------------------------------------- 987.3/987.3 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: urllib3 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from pmdarima>=1.8.0->darts) (1.26.14)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from pmdarima>=1.8.0->darts) (65.6.3)
# Collecting LunarCalendar>=0.0.9
#   Downloading LunarCalendar-0.0.9-py2.py3-none-any.whl (18 kB)
# Collecting cmdstanpy>=1.0.4
#   Downloading cmdstanpy-1.1.0-py3-none-any.whl (83 kB)
#      ---------------------------------------- 83.2/83.2 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: numba>=0.51 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from pyod>=0.9.5->darts) (0.56.4)
# Requirement already satisfied: tensorboard>=2.2.0 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from pytorch-lightning>=1.5.0->darts) (2.8.0)
# Requirement already satisfied: torchmetrics>=0.4.1 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from pytorch-lightning>=1.5.0->darts) (0.11.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from pytorch-lightning>=1.5.0->darts) (4.4.0)
# Requirement already satisfied: pyDeprecate>=0.3.1 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from pytorch-lightning>=1.5.0->darts) (0.3.2)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from pytorch-lightning>=1.5.0->darts) (2023.1.0)
# Requirement already satisfied: PyYAML>=5.4 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from pytorch-lightning>=1.5.0->darts) (6.0)
# Requirement already satisfied: protobuf<=3.20.1 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from pytorch-lightning>=1.5.0->darts) (3.20.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from requests>=2.22.0->darts) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from requests>=2.22.0->darts) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from requests>=2.22.0->darts) (2.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from scikit-learn>=1.0.1->darts) (2.2.0)
# Collecting cloudpickle
#   Downloading cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from statsmodels>=0.13.0->darts) (0.5.3)
# Requirement already satisfied: colorama in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from tqdm>=4.60.0->darts) (0.4.6)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.5.0->darts) (3.8.3)
# Collecting ephem>=3.7.5.3
#   Downloading ephem-4.1.4-cp38-cp38-win_amd64.whl (1.4 MB)
#      ---------------------------------------- 1.4/1.4 MB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from numba>=0.51->pyod>=0.9.5->darts) (6.0.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from numba>=0.51->pyod>=0.9.5->darts) (0.39.1)
# Requirement already satisfied: absl-py>=0.4 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.5.0->darts) (1.4.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.5.0->darts) (3.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.5.0->darts) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.5.0->darts) (2.16.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.5.0->darts) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.5.0->darts) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.5.0->darts) (2.2.2)
# Requirement already satisfied: grpcio>=1.24.3 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.5.0->darts) (1.43.0)
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.1.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.5.0->darts) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.5.0->darts) (1.3.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.5.0->darts) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.5.0->darts) (6.0.4)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.5.0->darts) (22.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.5.0->darts) (1.8.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.5.0->darts) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.5.0->darts) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.5.0->darts) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.5.0->darts) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from importlib-metadata->numba>=0.51->pyod>=0.9.5->darts) (3.12.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from werkzeug>=0.11.15->tensorboard>=2.2.0->pytorch-lightning>=1.5.0->darts) (2.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.5.0->darts) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\esko\anaconda3\envs\dl\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.5.0->darts) (3.2.2)
# Building wheels for collected packages: pyod, PyMeeus
#   Building wheel for pyod (setup.py): started
#   Building wheel for pyod (setup.py): finished with status 'done'
#   Created wheel for pyod: filename=pyod-1.0.7-py3-none-any.whl size=181085 sha256=873933ef78dae7d71adb1d370eb1bea9e87c4bb0d921d1c358b4713e8cb96aa9
#   Stored in directory: c:\users\esko\appdata\local\pip\cache\wheels\d1\3b\3a\23d2c32d0fb16e7d5afb28e379c310a2c6789e853976a941a3
#   Building wheel for PyMeeus (setup.py): started
#   Building wheel for PyMeeus (setup.py): finished with status 'done'
#   Created wheel for PyMeeus: filename=PyMeeus-0.5.12-py3-none-any.whl size=732001 sha256=4fb739abc96b3c5b1e7250ebcc83e72bfca17330ee7b688bfb222e6399cd310c
#   Stored in directory: c:\users\esko\appdata\local\pip\cache\wheels\b9\49\19\1ec4bcf2cc7640c6ee7815d9c02d06eaab89148fcd20e218c5
# Successfully built pyod PyMeeus
# Installing collected packages: PyMeeus, korean-lunar-calendar, ephem, tenacity, slicer, hijri-converter, graphviz, Cython, convertdate, cloudpickle, xgboost, plotly, LunarCalendar, holidays, xarray, shap, nfoursid, lightgbm, cmdstanpy, catboost, statsforecast, pyod, prophet, pmdarima, tbats, darts
# Successfully installed Cython-0.29.33 LunarCalendar-0.0.9 PyMeeus-0.5.12 catboost-1.1.1 cloudpickle-2.2.1 cmdstanpy-1.1.0 convertdate-2.4.0 darts-0.23.1 ephem-4.1.4 graphviz-0.20.1 hijri-converter-2.2.4 holidays-0.19 korean-lunar-calendar-0.3.1 lightgbm-3.3.5 nfoursid-1.0.1 plotly-5.13.0 pmdarima-2.0.2 prophet-1.1.2 pyod-1.0.7 shap-0.41.0 slicer-0.0.7 statsforecast-1.4.0 tbats-1.1.2 tenacity-8.1.0 xarray-2023.1.0 xgboost-1.7.3
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\esko\anaconda3\envs\dl\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\esko\anaconda3\envs\dl\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\esko\anaconda3\envs\dl\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\esko\anaconda3\envs\dl\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\esko\anaconda3\envs\dl\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\esko\anaconda3\envs\dl\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\esko\anaconda3\envs\dl\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\esko\anaconda3\envs\dl\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\esko\anaconda3\envs\dl\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\esko\anaconda3\envs\dl\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\esko\anaconda3\envs\dl\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\esko\anaconda3\envs\dl\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\esko\anaconda3\envs\dl\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\esko\anaconda3\envs\dl\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\esko\anaconda3\envs\dl\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\esko\anaconda3\envs\dl\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\esko\anaconda3\envs\dl\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\esko\anaconda3\envs\dl\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\esko\anaconda3\envs\dl\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\esko\anaconda3\envs\dl\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\esko\anaconda3\envs\dl\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\esko\anaconda3\envs\dl\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\esko\anaconda3\envs\dl\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\esko\anaconda3\envs\dl\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\esko\anaconda3\envs\dl\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\esko\anaconda3\envs\dl\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\esko\anaconda3\envs\dl\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\esko\anaconda3\envs\dl\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\esko\anaconda3\envs\dl\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\esko\anaconda3\envs\dl\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\esko\anaconda3\envs\dl\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\esko\anaconda3\envs\dl\lib\site-packages)

# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt

from darts import TimeSeries

import tensorflow as tf
tf.compat.v1.enable_eager_execution()

from tensorflow.keras.layers import MaxPool1D

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
plt.rcParams["figure.figsize"] = (9,6)

# %%
df = pd.read_csv('daily_traffic.csv')

df.head()
# Out:
#          date_time  traffic_volume
# 0  9/29/2016 17:00          5551.0
# 1  9/29/2016 18:00          4132.0
# 2  9/29/2016 19:00          3435.0
# 3  9/29/2016 20:00          2765.0
# 4  9/29/2016 21:00          2443.0

# %%
series = TimeSeries.from_dataframe(df, time_col='date_time')

series.plot()

# %%
train, test = series[:-120], series[-120:]

train.plot(label='train')
test.plot(label='test')

# %% [markdown]
# ## Baseline

# %%
from darts.models.forecasting.baselines import NaiveSeasonal

naive_seasonal = NaiveSeasonal(K=168)
naive_seasonal.fit(train)

pred_naive = naive_seasonal.predict(120)

# %%
test.plot(label='Actual')
pred_naive.plot(label='Baseline')

# %%
from darts.metrics import mae, mape

# naive_mae = mae(test, pred_naive)
naive_mae = mape(test, pred_naive)

# print(naive_mae)
print(naive_mape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 7
#       4 naive_mae = mape(test, pred_naive)
#       6 # print(naive_mae)
# ----> 7 print(naive_mape)
#
# NameError: name 'naive_mape' is not defined

# %% [markdown]
# ### Demonstrate MaxPool

# %%
maxpool_l4 = MaxPool1D(pool_size=4, strides=1, padding='same')
maxpool_l12 = MaxPool1D(pool_size=12, strides=1, padding='same')
maxpool_l24 = MaxPool1D(pool_size=24, strides=1, padding='same')

x = df['traffic_volume'].values
x = tf.reshape(x, [1, len(x), 1])

x_maxpooled_l4 = maxpool_l4(x).numpy().flatten()
x_maxpooled_l12 = maxpool_l12(x).numpy().flatten()
x_maxpooled_l24 = maxpool_l24(x).numpy().flatten()

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(nrows=4, ncols=1, figsize=(12,9))

ax1.plot(df['traffic_volume'])
ax1.set_ylabel('Data')

ax2.plot(x_maxpooled_l4)
ax2.set_ylabel('MaxPool l=4')

ax3.plot(x_maxpooled_l12)
ax3.set_ylabel('MaxPool l=12')

ax4.plot(x_maxpooled_l24)
ax4.set_ylabel('MaxPool l=24')

plt.tight_layout()

# %% [markdown]
# ## Apply N-HiTS

# %%
from darts.models import NHiTSModel
from darts.dataprocessing.transformers import Scaler

train_scaler = Scaler()
scaled_train = train_scaler.fit_transform(train)

nhits = NHiTSModel(
    input_chunk_length=168, 
    output_chunk_length=120,
    random_state=42)

nhits.fit(
    scaled_train,
    epochs=50)

scaled_pred_nhits = nhits.predict(n=120)
pred_nhits = train_scaler.inverse_transform(scaled_pred_nhits)

mae_nhits = mae(test, pred_nhits)

print(mae_nhits)
# Out:
# 2022-11-27 18:27:46 pytorch_lightning.utilities.rank_zero INFO: GPU available: False, used: False
# 2022-11-27 18:27:46 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-11-27 18:27:46 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-11-27 18:27:46 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-11-27 18:27:46 pytorch_lightning.callbacks.model_summary INFO:
#   | Name          | Type             | Params
# ---------------------------------------------------
# 0 | criterion     | MSELoss          | 0
# 1 | train_metrics | MetricCollection | 0
# 2 | val_metrics   | MetricCollection | 0
# 3 | stacks        | ModuleList       | 1.1 M
# ---------------------------------------------------
# 970 K     Trainable params
# 86.2 K    Non-trainable params
# 1.1 M     Total params
# 8.457     Total estimated model params size (MB)
# Epoch 49: 100%|███████████████████████████████████████| 19/19 [00:00<00:00, 40.69it/s, loss=0.0033, train_loss=0.00337]
# 2022-11-27 18:28:09 pytorch_lightning.utilities.rank_zero INFO: `Trainer.fit` stopped: `max_epochs=50` reached.
# Epoch 49: 100%|███████████████████████████████████████| 19/19 [00:00<00:00, 40.51it/s, loss=0.0033, train_loss=0.00337]
# Predicting DataLoader 0: 100%|██████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 166.67it/s]
# 266.32520849589866

# %%
test.plot(label='Actual')
pred_nhits.plot(label='N-HiTS')

# %%
fig, ax = plt.subplots()

x = ['Baseline', 'N-Beats', 'N-BEATS + covariates', 'N-HiTS']
y = [naive_mae, 292, 288, mae_nhits]

ax.bar(x, y, width=0.4)
ax.set_xlabel('Models')
ax.set_ylabel('MAE')
ax.set_ylim(0, 350)
ax.grid(False)

for index, value in enumerate(y):
    plt.text(x=index, y=value + 10, s=str(round(value,0)), ha='center')

plt.tight_layout()
